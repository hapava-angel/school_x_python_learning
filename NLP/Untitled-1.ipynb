# %%
# %pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
import nltk.tokenize
import timeit

# %%
book=open('Les_Miserables-Victor_Hugo.txt', 'r')
book.read()
# Out:
# '\tChapter one\n\n\tJean Valjean\n\n\tOne evening in October 1815, an hour before sunset, a man with a long beard and dusty, torn clothes walked into the town of Digne. He was in his late forties, of medium height, broad-shouldered and strong. A leather cap half-hid his face, which was sunburnt and shining with sweat. His rough yellow shirt was unbuttoned, revealing a hairy chest. On his back was a heavy soldier\'s bag, and in his hand was a large wooden stick.\n\n\tThe townspeople, who had never seen him before, watched with interest as he stopped for water at a fountain. Children followed him to the marketplace, where he stopped for more water at another fountain. He then crossed the square towards an inn, and entered by the kitchen door.\n\n\tThe innkeeper, who was also the cook, was busy with his pots and pans, preparing a meal for a group of travellers who were laughing and joking in the next room.\n\n\t\'What can I do for you, Monsieur?\' he asked without looking up.\n\n\t\'A m
# ...

# %%
book.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\linax\Desktop\IT\Новая папка\lecture\NLP\Untitled-1.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/linax/Desktop/IT/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/lecture/NLP/Untitled-1.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> book.split()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'split'

# %%
sentences = nltk.tokenize.sent_tokenize(book)
sentences
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# c:\Users\linax\Desktop\IT\Новая папка\lecture\NLP\Untitled-1.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/linax/Desktop/IT/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/lecture/NLP/Untitled-1.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> sentences = nltk.tokenize.sent_tokenize(book)
#       <a href='vscode-notebook-cell:/c%3A/Users/linax/Desktop/IT/%D0%9D%D0%BE%D0%B2%D0%B0%D1%8F%20%D0%BF%D0%B0%D0%BF%D0%BA%D0%B0/lecture/NLP/Untitled-1.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> sentences
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\nltk\tokenize\__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
#      97     """
# ...
